# %%
#importing the necessary libraries
import os
import numpy as np
import pandas as pd
import pathlib
import imageio
import matplotlib.pyplot as plt

# %%
# Exploring dataset
base_dir = '/content/drive/MyDrive/Chest X-Ray Images (Pneumonia)/'

train_pneumonia_dir = base_dir+'train/PNEUMONIA/'
train_normal_dir=base_dir+'train/NORMAL/'

test_pneumonia_dir = base_dir+'test/PNEUMONIA/'
test_normal_dir = base_dir+'test/NORMAL/'

val_normal_dir= base_dir+'val/NORMAL/'
val_pnrumonia_dir= base_dir+'val/PNEUMONIA/'

train_pn = [train_pneumonia_dir+"{}".format(i) for i in os.listdir(train_pneumonia_dir) ]
train_normal = [train_normal_dir+"{}".format(i) for i in os.listdir(train_normal_dir) ]

test_normal = [test_normal_dir+"{}".format(i) for i in os.listdir(test_normal_dir)]
test_pn = [test_pneumonia_dir+"{}".format(i) for i in os.listdir(test_pneumonia_dir)]

val_pn= [val_pnrumonia_dir+"{}".format(i) for i in os.listdir(val_pnrumonia_dir) ]
val_normal= [val_normal_dir+"{}".format(i) for i in os.listdir(val_normal_dir) ]

print ("Total images:",len(train_pn+train_normal+test_normal+test_pn+val_pn+val_normal))
print ("Total pneumonia images:",len(train_pn+test_pn+val_pn))
print ("Total Nomral images:",len(train_normal+test_normal+val_normal))
# Out:
# Total images: 5856
# Total pneumonia images: 4273
# Total Nomral images: 1583

# %%
# Dataset Splitting (train 80% , test 15% and validation 5% )

# Gathering all pneumina and normal chest X-ray in two python list
pn = train_pn + test_pn + val_pn
normal = train_normal + test_normal + val_normal

# Spliting dataset in train set,test set and validation set.

train_imgs = pn[:3418]+ normal[:1224]  # 80% of 4273 Pneumonia and normal chest X-ray are 3418 and 1224 respectively.
test_imgs = pn[3418:4059]+ normal[1224:1502]
val_imgs = pn[4059:] + normal[1502:]

print("Total Train Images %s containing %s pneumonia and %s normal images" % (len(train_imgs),len(pn[:3418]),len(normal[:1224])))
print("Total Test Images %s containing %s pneumonia and %s normal images" % (len(test_imgs),len(pn[3418:4059]),len(normal[1224:1502])))
print("Total validation Images %s containing %s pneumonia and %s normal images" % (len(val_imgs),len(pn[4059:]),len(normal[1502:])))

import random

random.shuffle(train_imgs)
random.shuffle(test_imgs)
random.shuffle(val_imgs)
# Out:
# Total Train Images 4642 containing 3418 pneumonia and 1224 normal images
# Total Test Images 919 containing 641 pneumonia and 278 normal images
# Total validation Images 295 containing 214 pneumonia and 81 normal images

# %%
import cv2
img_size = 224

def preprocess_image(image_list):

    X = [] # images
    y = [] #labels (0 for Normal or 1 for Pneumonia)
    count=0

    for image in image_list:

        try:

            img = cv2.imread(image,cv2.IMREAD_GRAYSCALE)

            img=cv2.resize(img,(img_size,img_size),interpolation=cv2.INTER_CUBIC)

            #converting image to 2D to 3D
            img = np.dstack([img, img, img])

            #convrt greyscaling image to RGB
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # Normalalizing Image
            img = img.astype(np.float32)/255.

            count=count+1

            X.append(img)


        except:
            continue
        #getting the labels
        if 'NORMAL' in image:
            y.append(0)

        elif 'IM' in image:
            y.append(0)

        elif 'virus' or 'bacteria' in image:
            y.append(1)


    return X, y

# %%
X, y = preprocess_image(train_imgs)

# %%
# Getting the labels for test set
P, t = preprocess_image(test_imgs)

# %%
# Getting the labels for validation set
K, m = preprocess_image(val_imgs)

# %%
from sklearn.utils import class_weight


class_weights = class_weight.compute_class_weight(class_weight = "balanced",
                                                  classes = np.unique(y), # here, y contains train set label
                                                  y = y)
class_weights = dict(enumerate(class_weights))
print(class_weights)
# Out:
# {0: 1.8962418300653594, 1: 0.679052077238151}

# %%
import seaborn as sns
import gc

train_imgs = train_pn[:3875]+ train_normal[:1341]
del train_imgs
gc.collect()

X_train = np.array(X)
y_train = np.array(y)
X_test = np.array(P)
y_test = np.array(t)
X_val = np.array(K)
y_val = np.array(m)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (4642, 224, 224, 3)
# (4642,)
# (919, 224, 224, 3)
# (919,)
# (295, 224, 224, 3)
# (295,)

# %%
# clearing memory
del X
del y
gc.collect()

#getting the length of the train and validation data
ntrain = len(X_train)
nval = len(X_val)

batch_size = 32

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(  rotation_range=7,
                                     width_shift_range=0.05,
                                     height_shift_range=0.05,
                                     shear_range=0.2,
                                     zoom_range=0.45,
                                     horizontal_flip=True)

val_datagen = ImageDataGenerator(zoom_range=0.45)

# %%
#Creating the image generators
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)

# %%
# Setting image Size
img_size =224

# %%
from keras import layers
from keras import models
from keras import optimizers
from keras.applications import *
from keras.layers import Dense, GlobalAveragePooling2D
from keras.preprocessing.image import img_to_array, load_img
from keras.models import Model
from keras import backend as K


# Creating the base pre-trained model
# Weights should be none becuase we don't need to train with any pre-trained weights here

base_model = ResNet50(weights='imagenet', include_top=False,input_shape=(img_size, img_size, 3))

x = base_model.output

# Adding a global spatial average pooling layer
x = GlobalAveragePooling2D()(x)

# Adding a logistic layer
predictions = Dense(1, activation="sigmoid")(x)

model = Model(inputs=base_model.input, outputs=predictions)
# Compiling model
model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step

# %%
# We can see details of  MobileNet architecure's details
# model.summary()

# %%
# We train for 64 epochs
history = model.fit_generator(train_generator,
                              steps_per_epoch=ntrain // batch_size,
                              epochs=64,
                              validation_data=val_generator,
                              validation_steps=nval // batch_size,
                              class_weight =class_weights,
)
# Out:
# <ipython-input-17-f41a3383dd5e>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# Epoch 1/64
# 145/145 [==============================] - 121s 531ms/step - loss: 0.3550 - binary_accuracy: 0.8709 - val_loss: 206.8694 - val_binary_accuracy: 0.7257
# Epoch 2/64
# 145/145 [==============================] - 80s 552ms/step - loss: 0.2013 - binary_accuracy: 0.9206 - val_loss: 26.6879 - val_binary_accuracy: 0.7222
# Epoch 3/64
# 145/145 [==============================] - 79s 539ms/step - loss: 0.1855 - binary_accuracy: 0.9258 - val_loss: 0.7708 - val_binary_accuracy: 0.7396
# Epoch 4/64
# 145/145 [==============================] - 77s 530ms/step - loss: 0.1622 - binary_accuracy: 0.9334 - val_loss: 1.3606 - val_binary_accuracy: 0.7222
# Epoch 5/64
# 145/145 [==============================] - 79s 545ms/step - loss: 0.1526 - binary_accuracy: 0.9371 - val_loss: 7.8960 - val_binary_accuracy: 0.7326
# Epoch 6/64
# 145/145 [==============================] - 78s 534ms/step - loss: 0.1717 - binary_accuracy: 0.9310 - val_loss: 1.0452 - val_binary_accuracy: 0.7812
# Epoch 7/64
# 145/145 [==============================] - 80s 548ms/step - loss: 0.1461 - binary_accuracy: 0.9460 - val_loss: 0.2971 - val_binary_accuracy: 0.8993
# Epoch 8/64
# 145/145 [==============================] - 79s 545ms/step - loss: 0.1649 - binary_accuracy: 0.9358 - val_loss: 1.4228 - val_binary_accuracy: 0.7292
# Epoch 9/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.1576 - binary_accuracy: 0.9382 - val_loss: 1.0304 - val_binary_accuracy: 0.7222
# Epoch 10/64
# 145/145 [==============================] - 77s 532ms/step - loss: 0.1449 - binary_accuracy: 0.9432 - val_loss: 1.2530 - val_binary_accuracy: 0.7431
# Epoch 11/64
# 145/145 [==============================] - 80s 552ms/step - loss: 0.1319 - binary_accuracy: 0.9479 - val_loss: 2.9318 - val_binary_accuracy: 0.4583
# Epoch 12/64
# 145/145 [==============================] - 77s 530ms/step - loss: 0.1327 - binary_accuracy: 0.9475 - val_loss: 0.9659 - val_binary_accuracy: 0.7812
# Epoch 13/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.1308 - binary_accuracy: 0.9505 - val_loss: 1.2226 - val_binary_accuracy: 0.7326
# Epoch 14/64
# 145/145 [==============================] - 79s 538ms/step - loss: 0.1307 - binary_accuracy: 0.9473 - val_loss: 5.5407 - val_binary_accuracy: 0.2778
# Epoch 15/64
# 145/145 [==============================] - 79s 544ms/step - loss: 0.1208 - binary_accuracy: 0.9536 - val_loss: 3.9057 - val_binary_accuracy: 0.7257
# Epoch 16/64
# 145/145 [==============================] - 79s 545ms/step - loss: 0.1187 - binary_accuracy: 0.9562 - val_loss: 1.5475 - val_binary_accuracy: 0.4757
# Epoch 17/64
# 145/145 [==============================] - 79s 544ms/step - loss: 0.1388 - binary_accuracy: 0.9451 - val_loss: 3.3259 - val_binary_accuracy: 0.4132
# Epoch 18/64
# 145/145 [==============================] - 77s 528ms/step - loss: 0.1346 - binary_accuracy: 0.9460 - val_loss: 2.0092 - val_binary_accuracy: 0.7292
# Epoch 19/64
# 145/145 [==============================] - 78s 541ms/step - loss: 0.1392 - binary_accuracy: 0.9512 - val_loss: 2.5257 - val_binary_accuracy: 0.4653
# Epoch 20/64
# 145/145 [==============================] - 78s 532ms/step - loss: 0.1790 - binary_accuracy: 0.9286 - val_loss: 16.0296 - val_binary_accuracy: 0.2778
# Epoch 21/64
# 145/145 [==============================] - 84s 576ms/step - loss: 0.2017 - binary_accuracy: 0.9150 - val_loss: 1.6300 - val_binary_accuracy: 0.7326
# Epoch 22/64
# 145/145 [==============================] - 77s 529ms/step - loss: 0.1629 - binary_accuracy: 0.9356 - val_loss: 3.3682 - val_binary_accuracy: 0.7396
# Epoch 23/64
# 145/145 [==============================] - 79s 541ms/step - loss: 0.1193 - binary_accuracy: 0.9510 - val_loss: 3.7003 - val_binary_accuracy: 0.3681
# Epoch 24/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.1366 - binary_accuracy: 0.9479 - val_loss: 0.4292 - val_binary_accuracy: 0.8264
# Epoch 25/64
# 145/145 [==============================] - 79s 544ms/step - loss: 0.1070 - binary_accuracy: 0.9560 - val_loss: 0.6413 - val_binary_accuracy: 0.7847
# Epoch 26/64
# 145/145 [==============================] - 84s 580ms/step - loss: 0.1238 - binary_accuracy: 0.9484 - val_loss: 2.6364 - val_binary_accuracy: 0.7361
# Epoch 27/64
# 145/145 [==============================] - 77s 530ms/step - loss: 0.1122 - binary_accuracy: 0.9566 - val_loss: 4.3227 - val_binary_accuracy: 0.3368
# Epoch 28/64
# 145/145 [==============================] - 79s 545ms/step - loss: 0.1204 - binary_accuracy: 0.9503 - val_loss: 0.4245 - val_binary_accuracy: 0.8576
# Epoch 29/64
# 145/145 [==============================] - 79s 541ms/step - loss: 0.1078 - binary_accuracy: 0.9581 - val_loss: 2.9900 - val_binary_accuracy: 0.4062
# Epoch 30/64
# 145/145 [==============================] - 77s 533ms/step - loss: 0.1070 - binary_accuracy: 0.9601 - val_loss: 2.1026 - val_binary_accuracy: 0.4826
# Epoch 31/64
# 145/145 [==============================] - 80s 547ms/step - loss: 0.1084 - binary_accuracy: 0.9603 - val_loss: 10.8739 - val_binary_accuracy: 0.2743
# Epoch 32/64
# 145/145 [==============================] - 78s 540ms/step - loss: 0.1122 - binary_accuracy: 0.9579 - val_loss: 6.0937 - val_binary_accuracy: 0.7188
# Epoch 33/64
# 145/145 [==============================] - 80s 548ms/step - loss: 0.0982 - binary_accuracy: 0.9631 - val_loss: 3.4520 - val_binary_accuracy: 0.7292
# Epoch 34/64
# 145/145 [==============================] - 79s 544ms/step - loss: 0.1118 - binary_accuracy: 0.9588 - val_loss: 6.7998 - val_binary_accuracy: 0.2951
# Epoch 35/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.1237 - binary_accuracy: 0.9512 - val_loss: 0.5183 - val_binary_accuracy: 0.8229
# Epoch 36/64
# 145/145 [==============================] - 80s 548ms/step - loss: 0.0987 - binary_accuracy: 0.9616 - val_loss: 0.6776 - val_binary_accuracy: 0.8021
# Epoch 37/64
# 145/145 [==============================] - 79s 542ms/step - loss: 0.1087 - binary_accuracy: 0.9586 - val_loss: 5.5941 - val_binary_accuracy: 0.7257
# Epoch 38/64
# 145/145 [==============================] - 78s 538ms/step - loss: 0.1013 - binary_accuracy: 0.9592 - val_loss: 3.4320 - val_binary_accuracy: 0.7257
# Epoch 39/64
# 145/145 [==============================] - 79s 542ms/step - loss: 0.1644 - binary_accuracy: 0.9354 - val_loss: 4.8535 - val_binary_accuracy: 0.3090
# Epoch 40/64
# 145/145 [==============================] - 77s 530ms/step - loss: 0.1314 - binary_accuracy: 0.9486 - val_loss: 2.9065 - val_binary_accuracy: 0.3264
# Epoch 41/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.1150 - binary_accuracy: 0.9540 - val_loss: 1.2847 - val_binary_accuracy: 0.7431
# Epoch 42/64
# 145/145 [==============================] - 77s 529ms/step - loss: 0.1085 - binary_accuracy: 0.9601 - val_loss: 1.3087 - val_binary_accuracy: 0.7361
# Epoch 43/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.0909 - binary_accuracy: 0.9642 - val_loss: 2.3334 - val_binary_accuracy: 0.7326
# Epoch 44/64
# 145/145 [==============================] - 78s 539ms/step - loss: 0.0983 - binary_accuracy: 0.9636 - val_loss: 0.7937 - val_binary_accuracy: 0.7708
# Epoch 45/64
# 145/145 [==============================] - 78s 537ms/step - loss: 0.0929 - binary_accuracy: 0.9657 - val_loss: 1.5970 - val_binary_accuracy: 0.7257
# Epoch 46/64
# 145/145 [==============================] - 76s 521ms/step - loss: 0.1025 - binary_accuracy: 0.9590 - val_loss: 0.3681 - val_binary_accuracy: 0.8750
# Epoch 47/64
# 145/145 [==============================] - 78s 537ms/step - loss: 0.0875 - binary_accuracy: 0.9672 - val_loss: 0.2577 - val_binary_accuracy: 0.8924
# Epoch 48/64
# 145/145 [==============================] - 81s 553ms/step - loss: 0.0855 - binary_accuracy: 0.9675 - val_loss: 2.6007 - val_binary_accuracy: 0.7222
# Epoch 49/64
# 145/145 [==============================] - 79s 541ms/step - loss: 0.0952 - binary_accuracy: 0.9633 - val_loss: 0.7646 - val_binary_accuracy: 0.6840
# Epoch 50/64
# 145/145 [==============================] - 77s 528ms/step - loss: 0.0799 - binary_accuracy: 0.9701 - val_loss: 0.4740 - val_binary_accuracy: 0.8264
# Epoch 51/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.0844 - binary_accuracy: 0.9644 - val_loss: 2.2096 - val_binary_accuracy: 0.4896
# Epoch 52/64
# 145/145 [==============================] - 77s 532ms/step - loss: 0.0936 - binary_accuracy: 0.9620 - val_loss: 4.3080 - val_binary_accuracy: 0.3611
# Epoch 53/64
# 145/145 [==============================] - 84s 579ms/step - loss: 0.0872 - binary_accuracy: 0.9666 - val_loss: 0.2477 - val_binary_accuracy: 0.9028
# Epoch 54/64
# 145/145 [==============================] - 79s 542ms/step - loss: 0.0828 - binary_accuracy: 0.9668 - val_loss: 1.6108 - val_binary_accuracy: 0.7465
# Epoch 55/64
# 145/145 [==============================] - 78s 534ms/step - loss: 0.0858 - binary_accuracy: 0.9659 - val_loss: 0.4003 - val_binary_accuracy: 0.8472
# Epoch 56/64
# 145/145 [==============================] - 79s 542ms/step - loss: 0.0960 - binary_accuracy: 0.9644 - val_loss: 0.5928 - val_binary_accuracy: 0.7257
# Epoch 57/64
# 145/145 [==============================] - 77s 530ms/step - loss: 0.0974 - binary_accuracy: 0.9651 - val_loss: 5.6982 - val_binary_accuracy: 0.7222
# Epoch 58/64
# 145/145 [==============================] - 82s 559ms/step - loss: 0.0855 - binary_accuracy: 0.9664 - val_loss: 1.4999 - val_binary_accuracy: 0.5347
# Epoch 59/64
# 145/145 [==============================] - 80s 547ms/step - loss: 0.0778 - binary_accuracy: 0.9690 - val_loss: 9.8687 - val_binary_accuracy: 0.2778
# Epoch 60/64
# 145/145 [==============================] - 79s 541ms/step - loss: 0.1029 - binary_accuracy: 0.9584 - val_loss: 3.3584 - val_binary_accuracy: 0.7257
# Epoch 61/64
# 145/145 [==============================] - 79s 541ms/step - loss: 0.1450 - binary_accuracy: 0.9460 - val_loss: 1.9873 - val_binary_accuracy: 0.5521
# Epoch 62/64
# 145/145 [==============================] - 80s 548ms/step - loss: 0.0886 - binary_accuracy: 0.9662 - val_loss: 2.3851 - val_binary_accuracy: 0.4132
# Epoch 63/64
# 145/145 [==============================] - 80s 554ms/step - loss: 0.0863 - binary_accuracy: 0.9664 - val_loss: 3.2010 - val_binary_accuracy: 0.3229
# Epoch 64/64
# 145/145 [==============================] - 81s 558ms/step - loss: 0.0913 - binary_accuracy: 0.9666 - val_loss: 0.9927 - val_binary_accuracy: 0.7465

# %%
# Lets plot the train and val curve
# Getting the details form the history object
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

#Training and validating accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()
#Training and validating loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

preds = model.predict(X_test)

acc = accuracy_score(y_test, np.round(preds))*100
cm = confusion_matrix(y_test, np.round(preds))

tn, fp, fn, tp = cm.ravel()

print('CONFUSION MATRIX ------------------')
print(cm)

print('\n============TEST METRICS=============')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(acc))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))

print('\nTRAIN METRIC ----------------------')
print('Train acc: {}'.format(np.round((history.history['binary_accuracy'][-1])*100, 2)))
# Out:
# 29/29 [==============================] - 5s 135ms/step
# CONFUSION MATRIX ------------------
# [[ 88 190]
#  [  0 641]]
#
# ============TEST METRICS=============
# Accuracy: 79.32535364526659%
# Precision: 77.13598074608905%
# Recall: 100.0%
# F1-score: 87.09239130434783
#
# TRAIN METRIC ----------------------
# Train acc: 96.66

# %%
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d",)
# Out:
# <Axes: >

# %%
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import auc

fpr , tpr , thresholds = roc_curve ( y_test , preds)
auc_keras = auc(fpr, tpr)
print("AUC Score:",auc_keras)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc_keras)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC Score: 0.9636555965835756
