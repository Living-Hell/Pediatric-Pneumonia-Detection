# %%
#importing the necessary libraries
import os
import numpy as np
import pandas as pd
import pathlib
import imageio
import matplotlib.pyplot as plt

# %%
# Exploring dataset
base_dir = '/content/drive/MyDrive/Chest X-Ray Images (Pneumonia)/'

train_pneumonia_dir = base_dir+'train/PNEUMONIA/'
train_normal_dir=base_dir+'train/NORMAL/'

test_pneumonia_dir = base_dir+'test/PNEUMONIA/'
test_normal_dir = base_dir+'test/NORMAL/'

val_normal_dir= base_dir+'val/NORMAL/'
val_pnrumonia_dir= base_dir+'val/PNEUMONIA/'

train_pn = [train_pneumonia_dir+"{}".format(i) for i in os.listdir(train_pneumonia_dir) ]
train_normal = [train_normal_dir+"{}".format(i) for i in os.listdir(train_normal_dir) ]

test_normal = [test_normal_dir+"{}".format(i) for i in os.listdir(test_normal_dir)]
test_pn = [test_pneumonia_dir+"{}".format(i) for i in os.listdir(test_pneumonia_dir)]

val_pn= [val_pnrumonia_dir+"{}".format(i) for i in os.listdir(val_pnrumonia_dir) ]
val_normal= [val_normal_dir+"{}".format(i) for i in os.listdir(val_normal_dir) ]

print ("Total images:",len(train_pn+train_normal+test_normal+test_pn+val_pn+val_normal))
print ("Total pneumonia images:",len(train_pn+test_pn+val_pn))
print ("Total Nomral images:",len(train_normal+test_normal+val_normal))
# Out:
# Total images: 5856
# Total pneumonia images: 4273
# Total Nomral images: 1583

# %%
# Dataset Splitting (train 80% , test 15% and validation 5% )

# Gathering all pneumina and normal chest X-ray in two python list
pn = train_pn + test_pn + val_pn
normal = train_normal + test_normal + val_normal

# Spliting dataset in train set,test set and validation set.

train_imgs = pn[:3418]+ normal[:1224]  # 80% of 4273 Pneumonia and normal chest X-ray are 3418 and 1224 respectively.
test_imgs = pn[3418:4059]+ normal[1224:1502]
val_imgs = pn[4059:] + normal[1502:]

print("Total Train Images %s containing %s pneumonia and %s normal images" % (len(train_imgs),len(pn[:3418]),len(normal[:1224])))
print("Total Test Images %s containing %s pneumonia and %s normal images" % (len(test_imgs),len(pn[3418:4059]),len(normal[1224:1502])))
print("Total validation Images %s containing %s pneumonia and %s normal images" % (len(val_imgs),len(pn[4059:]),len(normal[1502:])))

import random

random.shuffle(train_imgs)
random.shuffle(test_imgs)
random.shuffle(val_imgs)
# Out:
# Total Train Images 4642 containing 3418 pneumonia and 1224 normal images
# Total Test Images 919 containing 641 pneumonia and 278 normal images
# Total validation Images 295 containing 214 pneumonia and 81 normal images

# %%
import cv2
img_size = 224

def preprocess_image(image_list):

    X = [] # images
    y = [] #labels (0 for Normal or 1 for Pneumonia)
    count=0

    for image in image_list:

        try:

            img = cv2.imread(image,cv2.IMREAD_GRAYSCALE)

            img=cv2.resize(img,(img_size,img_size),interpolation=cv2.INTER_CUBIC)

            #converting image to 2D to 3D
            img = np.dstack([img, img, img])

            #convrt greyscaling image to RGB
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

            # Normalalizing Image
            img = img.astype(np.float32)/255.

            count=count+1

            X.append(img)


        except:
            continue
        #getting the labels
        if 'NORMAL' in image:
            y.append(0)

        elif 'IM' in image:
            y.append(0)

        elif 'virus' or 'bacteria' in image:
            y.append(1)


    return X, y

# %%
X, y = preprocess_image(train_imgs)

# %%
# Getting the labels for test set
P, t = preprocess_image(test_imgs)

# %%
# Getting the labels for validation set
K, m = preprocess_image(val_imgs)

# %%
from sklearn.utils import class_weight


class_weights = class_weight.compute_class_weight(class_weight = "balanced",
                                                  classes = np.unique(y), # here, y contains train set label
                                                  y = y)
class_weights = dict(enumerate(class_weights))
print(class_weights)
# Out:
# {0: 1.8962418300653594, 1: 0.679052077238151}

# %%
import seaborn as sns
import gc

train_imgs = train_pn[:3875]+ train_normal[:1341]
del train_imgs
gc.collect()

X_train = np.array(X)
y_train = np.array(y)
X_test = np.array(P)
y_test = np.array(t)
X_val = np.array(K)
y_val = np.array(m)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (4642, 224, 224, 3)
# (4642,)
# (919, 224, 224, 3)
# (919,)
# (295, 224, 224, 3)
# (295,)

# %%
# clearing memory
del X
del y
gc.collect()

#getting the length of the train and validation data
ntrain = len(X_train)
nval = len(X_val)

batch_size = 32

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(  rotation_range=7,
                                     width_shift_range=0.05,
                                     height_shift_range=0.05,
                                     shear_range=0.2,
                                     zoom_range=0.45,
                                     horizontal_flip=True)

val_datagen = ImageDataGenerator(zoom_range=0.45)

# %%
#Creating the image generators
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)

# %%
# Setting image Size
img_size =224

# %%
from keras import layers
from keras import models
from keras import optimizers
from keras.applications import *
from keras.layers import Dense, GlobalAveragePooling2D
from keras.preprocessing.image import img_to_array, load_img
from keras.models import Model
from keras import backend as K


# Creating the base pre-trained model
# Weights should be none becuase we don't need to train with any pre-trained weights here

base_model = ResNet50(weights='imagenet', include_top=False,input_shape=(img_size, img_size, 3))

x = base_model.output

# Adding a global spatial average pooling layer
x = GlobalAveragePooling2D()(x)

# Adding a logistic layer
predictions = Dense(1, activation="sigmoid")(x)

model = Model(inputs=base_model.input, outputs=predictions)
# Compiling model
model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['binary_accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
# We can see details of  MobileNet architecure's details
# model.summary()

# %%
# We train for 64 epochs
history = model.fit_generator(train_generator,
                              steps_per_epoch=ntrain // batch_size,
                              epochs=64,
                              validation_data=val_generator,
                              validation_steps=nval // batch_size,
                              class_weight =class_weights,
)
# Out:
# <ipython-input-19-f41a3383dd5e>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_generator,
# Epoch 1/64
# 145/145 [==============================] - 122s 539ms/step - loss: 0.3496 - binary_accuracy: 0.8698 - val_loss: 4.9046 - val_binary_accuracy: 0.7292
# Epoch 2/64
# 145/145 [==============================] - 77s 527ms/step - loss: 0.2744 - binary_accuracy: 0.8872 - val_loss: 2.7415 - val_binary_accuracy: 0.7292
# Epoch 3/64
# 145/145 [==============================] - 80s 554ms/step - loss: 0.2425 - binary_accuracy: 0.9030 - val_loss: 60.6707 - val_binary_accuracy: 0.7257
# Epoch 4/64
# 145/145 [==============================] - 78s 540ms/step - loss: 0.2338 - binary_accuracy: 0.9046 - val_loss: 23.8726 - val_binary_accuracy: 0.7222
# Epoch 5/64
# 145/145 [==============================] - 80s 551ms/step - loss: 0.2135 - binary_accuracy: 0.9108 - val_loss: 3.4553 - val_binary_accuracy: 0.7257
# Epoch 6/64
# 145/145 [==============================] - 76s 522ms/step - loss: 0.1785 - binary_accuracy: 0.9273 - val_loss: 0.8261 - val_binary_accuracy: 0.7604
# Epoch 7/64
# 145/145 [==============================] - 78s 534ms/step - loss: 0.1933 - binary_accuracy: 0.9234 - val_loss: 0.4864 - val_binary_accuracy: 0.7951
# Epoch 8/64
# 145/145 [==============================] - 79s 546ms/step - loss: 0.1646 - binary_accuracy: 0.9347 - val_loss: 2.1242 - val_binary_accuracy: 0.7257
# Epoch 9/64
# 145/145 [==============================] - 80s 548ms/step - loss: 0.1641 - binary_accuracy: 0.9358 - val_loss: 0.8051 - val_binary_accuracy: 0.7431
# Epoch 10/64
# 145/145 [==============================] - 77s 529ms/step - loss: 0.1557 - binary_accuracy: 0.9367 - val_loss: 1.9484 - val_binary_accuracy: 0.5521
# Epoch 11/64
# 145/145 [==============================] - 78s 540ms/step - loss: 0.1634 - binary_accuracy: 0.9330 - val_loss: 1.4394 - val_binary_accuracy: 0.7222
# Epoch 12/64
# 145/145 [==============================] - 80s 550ms/step - loss: 0.1515 - binary_accuracy: 0.9425 - val_loss: 0.8720 - val_binary_accuracy: 0.7292
# Epoch 13/64
# 145/145 [==============================] - 79s 546ms/step - loss: 0.1354 - binary_accuracy: 0.9449 - val_loss: 2.7493 - val_binary_accuracy: 0.7292
# Epoch 14/64
# 145/145 [==============================] - 79s 541ms/step - loss: 0.1369 - binary_accuracy: 0.9479 - val_loss: 3.4176 - val_binary_accuracy: 0.7188
# Epoch 15/64
# 145/145 [==============================] - 78s 538ms/step - loss: 0.1411 - binary_accuracy: 0.9456 - val_loss: 1.7556 - val_binary_accuracy: 0.7326
# Epoch 16/64
# 145/145 [==============================] - 79s 547ms/step - loss: 0.1180 - binary_accuracy: 0.9518 - val_loss: 0.5866 - val_binary_accuracy: 0.8681
# Epoch 17/64
# 145/145 [==============================] - 76s 525ms/step - loss: 0.1374 - binary_accuracy: 0.9453 - val_loss: 1.3629 - val_binary_accuracy: 0.5694
# Epoch 18/64
# 145/145 [==============================] - 78s 538ms/step - loss: 0.1514 - binary_accuracy: 0.9397 - val_loss: 1.6870 - val_binary_accuracy: 0.7396
# Epoch 19/64
# 145/145 [==============================] - 78s 539ms/step - loss: 0.1339 - binary_accuracy: 0.9499 - val_loss: 0.8962 - val_binary_accuracy: 0.6979
# Epoch 20/64
# 145/145 [==============================] - 78s 539ms/step - loss: 0.1312 - binary_accuracy: 0.9477 - val_loss: 1.5231 - val_binary_accuracy: 0.7292
# Epoch 21/64
# 145/145 [==============================] - 79s 544ms/step - loss: 0.1157 - binary_accuracy: 0.9549 - val_loss: 11.1324 - val_binary_accuracy: 0.7257
# Epoch 22/64
# 145/145 [==============================] - 80s 546ms/step - loss: 0.1217 - binary_accuracy: 0.9551 - val_loss: 0.8951 - val_binary_accuracy: 0.8125
# Epoch 23/64
# 145/145 [==============================] - 78s 538ms/step - loss: 0.1265 - binary_accuracy: 0.9499 - val_loss: 3.5672 - val_binary_accuracy: 0.3160
# Epoch 24/64
# 145/145 [==============================] - 77s 529ms/step - loss: 0.1163 - binary_accuracy: 0.9557 - val_loss: 6.4556 - val_binary_accuracy: 0.2743
# Epoch 25/64
# 145/145 [==============================] - 80s 547ms/step - loss: 0.1425 - binary_accuracy: 0.9471 - val_loss: 1.7613 - val_binary_accuracy: 0.5000
# Epoch 26/64
# 145/145 [==============================] - 76s 525ms/step - loss: 0.1324 - binary_accuracy: 0.9477 - val_loss: 4.3491 - val_binary_accuracy: 0.7292
# Epoch 27/64
# 145/145 [==============================] - 78s 539ms/step - loss: 0.1271 - binary_accuracy: 0.9523 - val_loss: 7.1175 - val_binary_accuracy: 0.3472
# Epoch 28/64
# 145/145 [==============================] - 80s 551ms/step - loss: 0.1698 - binary_accuracy: 0.9369 - val_loss: 1.6446 - val_binary_accuracy: 0.5833
# Epoch 29/64
# 145/145 [==============================] - 79s 542ms/step - loss: 0.1160 - binary_accuracy: 0.9542 - val_loss: 12.9574 - val_binary_accuracy: 0.2778
# Epoch 30/64
# 145/145 [==============================] - 80s 553ms/step - loss: 0.1206 - binary_accuracy: 0.9542 - val_loss: 0.3532 - val_binary_accuracy: 0.8403
# Epoch 31/64
# 145/145 [==============================] - 80s 554ms/step - loss: 0.1093 - binary_accuracy: 0.9581 - val_loss: 2.5073 - val_binary_accuracy: 0.7326
# Epoch 32/64
# 145/145 [==============================] - 77s 532ms/step - loss: 0.1189 - binary_accuracy: 0.9544 - val_loss: 0.4501 - val_binary_accuracy: 0.8229
# Epoch 33/64
# 145/145 [==============================] - 79s 542ms/step - loss: 0.1050 - binary_accuracy: 0.9594 - val_loss: 0.4248 - val_binary_accuracy: 0.8368
# Epoch 34/64
# 145/145 [==============================] - 81s 557ms/step - loss: 0.1166 - binary_accuracy: 0.9523 - val_loss: 0.3833 - val_binary_accuracy: 0.8542
# Epoch 35/64
# 145/145 [==============================] - 78s 538ms/step - loss: 0.1226 - binary_accuracy: 0.9531 - val_loss: 5.4566 - val_binary_accuracy: 0.3021
# Epoch 36/64
# 145/145 [==============================] - 80s 548ms/step - loss: 0.1348 - binary_accuracy: 0.9456 - val_loss: 4.1298 - val_binary_accuracy: 0.7222
# Epoch 37/64
# 145/145 [==============================] - 76s 524ms/step - loss: 0.1125 - binary_accuracy: 0.9573 - val_loss: 1.7205 - val_binary_accuracy: 0.5139
# Epoch 38/64
# 145/145 [==============================] - 76s 526ms/step - loss: 0.1078 - binary_accuracy: 0.9584 - val_loss: 2.6583 - val_binary_accuracy: 0.4861
# Epoch 39/64
# 145/145 [==============================] - 79s 547ms/step - loss: 0.1050 - binary_accuracy: 0.9577 - val_loss: 2.4182 - val_binary_accuracy: 0.7292
# Epoch 40/64
# 145/145 [==============================] - 78s 539ms/step - loss: 0.1164 - binary_accuracy: 0.9510 - val_loss: 0.9707 - val_binary_accuracy: 0.7535
# Epoch 41/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.1122 - binary_accuracy: 0.9566 - val_loss: 2.5420 - val_binary_accuracy: 0.7222
# Epoch 42/64
# 145/145 [==============================] - 80s 549ms/step - loss: 0.1064 - binary_accuracy: 0.9586 - val_loss: 2.7517 - val_binary_accuracy: 0.7396
# Epoch 43/64
# 145/145 [==============================] - 81s 557ms/step - loss: 0.1114 - binary_accuracy: 0.9568 - val_loss: 3.6847 - val_binary_accuracy: 0.3299
# Epoch 44/64
# 145/145 [==============================] - 79s 541ms/step - loss: 0.1019 - binary_accuracy: 0.9607 - val_loss: 1.9287 - val_binary_accuracy: 0.7257
# Epoch 45/64
# 145/145 [==============================] - 78s 535ms/step - loss: 0.1141 - binary_accuracy: 0.9538 - val_loss: 0.5742 - val_binary_accuracy: 0.8299
# Epoch 46/64
# 145/145 [==============================] - 77s 528ms/step - loss: 0.1096 - binary_accuracy: 0.9584 - val_loss: 10.7446 - val_binary_accuracy: 0.2778
# Epoch 47/64
# 145/145 [==============================] - 80s 546ms/step - loss: 0.1121 - binary_accuracy: 0.9590 - val_loss: 3.6892 - val_binary_accuracy: 0.7292
# Epoch 48/64
# 145/145 [==============================] - 79s 547ms/step - loss: 0.0953 - binary_accuracy: 0.9653 - val_loss: 3.2103 - val_binary_accuracy: 0.3958
# Epoch 49/64
# 145/145 [==============================] - 76s 522ms/step - loss: 0.0940 - binary_accuracy: 0.9623 - val_loss: 1.4679 - val_binary_accuracy: 0.7465
# Epoch 50/64
# 145/145 [==============================] - 76s 526ms/step - loss: 0.1027 - binary_accuracy: 0.9644 - val_loss: 6.0642 - val_binary_accuracy: 0.2986
# Epoch 51/64
# 145/145 [==============================] - 78s 536ms/step - loss: 0.0973 - binary_accuracy: 0.9649 - val_loss: 1.2885 - val_binary_accuracy: 0.7292
# Epoch 52/64
# 145/145 [==============================] - 79s 544ms/step - loss: 0.0968 - binary_accuracy: 0.9625 - val_loss: 0.9832 - val_binary_accuracy: 0.7257
# Epoch 53/64
# 145/145 [==============================] - 79s 542ms/step - loss: 0.0927 - binary_accuracy: 0.9631 - val_loss: 17.9136 - val_binary_accuracy: 0.7257
# Epoch 54/64
# 145/145 [==============================] - 80s 551ms/step - loss: 0.0960 - binary_accuracy: 0.9605 - val_loss: 12.5861 - val_binary_accuracy: 0.2743
# Epoch 55/64
# 145/145 [==============================] - 78s 539ms/step - loss: 0.0827 - binary_accuracy: 0.9681 - val_loss: 0.8449 - val_binary_accuracy: 0.7674
# Epoch 56/64
# 145/145 [==============================] - 78s 537ms/step - loss: 0.0912 - binary_accuracy: 0.9627 - val_loss: 12.9786 - val_binary_accuracy: 0.2743
# Epoch 57/64
# 145/145 [==============================] - 80s 548ms/step - loss: 0.0893 - binary_accuracy: 0.9638 - val_loss: 0.7293 - val_binary_accuracy: 0.7951
# Epoch 58/64
# 145/145 [==============================] - 79s 539ms/step - loss: 0.0858 - binary_accuracy: 0.9692 - val_loss: 7.5807 - val_binary_accuracy: 0.7326
# Epoch 59/64
# 145/145 [==============================] - 77s 532ms/step - loss: 0.1035 - binary_accuracy: 0.9607 - val_loss: 0.4039 - val_binary_accuracy: 0.8229
# Epoch 60/64
# 145/145 [==============================] - 78s 535ms/step - loss: 0.0985 - binary_accuracy: 0.9614 - val_loss: 3.2884 - val_binary_accuracy: 0.4097
# Epoch 61/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.1097 - binary_accuracy: 0.9601 - val_loss: 2.1828 - val_binary_accuracy: 0.7292
# Epoch 62/64
# 145/145 [==============================] - 78s 535ms/step - loss: 0.0937 - binary_accuracy: 0.9644 - val_loss: 9.1926 - val_binary_accuracy: 0.7292
# Epoch 63/64
# 145/145 [==============================] - 81s 557ms/step - loss: 0.0938 - binary_accuracy: 0.9642 - val_loss: 12.9342 - val_binary_accuracy: 0.7257
# Epoch 64/64
# 145/145 [==============================] - 79s 543ms/step - loss: 0.0926 - binary_accuracy: 0.9668 - val_loss: 11.8127 - val_binary_accuracy: 0.2812

# %%
# Lets plot the train and val curve
# Getting the details form the history object
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

#Training and validating accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()
#Training and validating loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

preds = model.predict(X_test)

acc = accuracy_score(y_test, np.round(preds))*100
cm = confusion_matrix(y_test, np.round(preds))

tn, fp, fn, tp = cm.ravel()

print('CONFUSION MATRIX ------------------')
print(cm)

print('\n============TEST METRICS=============')
precision = tp/(tp+fp)*100
recall = tp/(tp+fn)*100
print('Accuracy: {}%'.format(acc))
print('Precision: {}%'.format(precision))
print('Recall: {}%'.format(recall))
print('F1-score: {}'.format(2*precision*recall/(precision+recall)))

print('\nTRAIN METRIC ----------------------')
print('Train acc: {}'.format(np.round((history.history['binary_accuracy'][-1])*100, 2)))
# Out:
# 29/29 [==============================] - 5s 135ms/step
# CONFUSION MATRIX ------------------
# [[278   0]
#  [641   0]]
#
# ============TEST METRICS=============
# Accuracy: 30.25027203482046%
# Precision: nan%
# Recall: 0.0%
# F1-score: nan
#
# TRAIN METRIC ----------------------
# Train acc: 96.68
# <ipython-input-21-6f4c03adfd1e>:14: RuntimeWarning: invalid value encountered in long_scalars
#   precision = tp/(tp+fp)*100

# %%
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d",)
# Out:
# <Axes: >

# %%
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import auc

fpr , tpr , thresholds = roc_curve ( y_test , preds)
auc_keras = auc(fpr, tpr)
print("AUC Score:",auc_keras)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc_keras)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC Score: 0.7752051089237814
